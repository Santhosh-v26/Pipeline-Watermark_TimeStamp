-- %%
create schema if not exists main.watermark

-- %%
create table if not exists main.watermark.watermark_orders(
  watermark timestamp
);
insert into main.watermark.watermark_orders values('2000-01-01 00:00')

-- %%
create table if not exists main.watermark.watermark_payments(
  watermark timestamp
);
insert into main.watermark.watermark_payments values('2000-01-01 00:00')

-- %%
create schema main.raw_task;
create schema main.silver_task;
create schema main.gold_task;
